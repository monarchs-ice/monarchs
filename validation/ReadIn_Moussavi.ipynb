# %%
#Code to read in Moussavi et al. (2020) Landsat lake data

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt


# Path to the file
#file_path = "Publications/124-109/LC08_L1GT_124109_20131213_20170427_01_T2/LC08_L1GT_124109_20131213_20170427_01_T2_All_Masks.tif"
file_path="LC08_L1GT_124109_20131213_20170427_01_T2_All_Masks.tif"

im = Image.open(file_path)
im.show()

imarray = np.array(im)

print(imarray.shape)
print(imarray.size)

# Create a figure and plot the data
fig = plt.figure()
plt.imshow(imarray)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1836\3489306178.py in <module>
#      10 file_path="LC08_L1GT_124109_20131213_20170427_01_T2_All_Masks.tif"
#      11
# ---> 12 im = Image.open(file_path)
#      13 im.show()
#      14
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3145     for message in accept_warnings:
#    3146         warnings.warn(message)
# -> 3147     raise UnidentifiedImageError(
#    3148         "cannot identify image file %r" % (filename if filename else fp)
#    3149     )
#
# UnidentifiedImageError: cannot identify image file 'LC08_L1GT_124109_20131213_20170427_01_T2_All_Masks.tif'

# %%
from geotiff import GeoTiff
import matplotlib.pyplot as plt
import numpy as np

#define file path so it actually words
#create function to sample a smaller bounding box (use read box exisiting function https://pypi.org/project/geotiff/)
#create function to get histogram of lake depths

geo_tiff = GeoTiff(file_path, crs_code=4326) #Had to guess crs
geo_tiff.tif_shape
geo_tiff.tif_bBox
zarr_array = geo_tiff.read()
array = np.array(zarr_array)
fig = plt.figure()
plt.imshow(array)
plt.show()
